# %% [markdown]
# # Task 2

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('Stipend_Data.csv')

x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 1/3,random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x_train,y_train)

y_predict = regressor.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='Red')

# %%
plt.plot(x_train,regressor.predict(x_train),color='Blue')
plt.scatter(x_train,y_train,color='Red')
plt.title("Training Data Analysis")
plt.xlabel("Years of Experience")
plt.ylabel("Stipend")
# Out:
# Text(0, 0.5, 'Stipend')

# %%
plt.scatter(x_test,y_test,color='Red')

# %%
plt.plot(x_train,regressor.predict(x_train),color='Blue')
plt.scatter(x_test,y_test,color='Red')
plt.title("Testing Data Analysis")
plt.xlabel("Years of Experience")
plt.ylabel("Stipend")
# Out:
# Text(0, 0.5, 'Stipend')

# %% [markdown]
# # Task 3

# %%
from sklearn import metrics

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y_test,y_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y_test,y_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y_test,y_predict)))
# Out:
# Mean Absolute Error (MAE) is:  3426.4269374307123
# Mean Squared Error (MSE) is:  21026037.329511296
# Root Mean Squared Error (RMSE) is:  4585.4157204675885

# %% [markdown]
# # Task 4

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

dataset2 = pd.read_csv("kc_house_data.csv")

# %%
y2 = dataset2['price'].values.reshape(-1,1)

# %% [markdown]
# ## Now we take different attributes for x to get minimum error

# %%
x2 = dataset2['sqft_living'].values.reshape(-1,1)
from sklearn.model_selection import train_test_split

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

from sklearn import metrics

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  172649.01126504186
# Mean Squared Error (MSE) is:  72169122334.16643
# Root Mean Squared Error (RMSE) is:  268643.1133198214

# %%
x2 = dataset2['bedrooms'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  225341.12698523412
# Mean Squared Error (MSE) is:  131470655109.96173
# Root Mean Squared Error (RMSE) is:  362588.8237521418

# %%
x2 = dataset2['bathrooms'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  203882.5771255971
# Mean Squared Error (MSE) is:  103190662477.37401
# Root Mean Squared Error (RMSE) is:  321233.03453626

# %%
x2 = dataset2['sqft_lot'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  234573.87764346402
# Mean Squared Error (MSE) is:  143449952709.38867
# Root Mean Squared Error (RMSE) is:  378747.8748579174

# %%
x2 = dataset2['floors'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  224415.41492155963
# Mean Squared Error (MSE) is:  134884776334.74515
# Root Mean Squared Error (RMSE) is:  367266.6283978782

# %%
x2 = dataset2['condition'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  236075.47953886728
# Mean Squared Error (MSE) is:  144374583215.7285
# Root Mean Squared Error (RMSE) is:  379966.55539103504

# %%
x2 = dataset2['grade'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  173522.71927741775
# Mean Squared Error (MSE) is:  80086695856.59132
# Root Mean Squared Error (RMSE) is:  282995.9290459694

# %%
x2 = dataset2['sqft_above'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  191004.46156671052
# Mean Squared Error (MSE) is:  90674981867.27078
# Root Mean Squared Error (RMSE) is:  301122.86838975013

# %%
x2 = dataset2['sqft_basement'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  226534.8582877186
# Mean Squared Error (MSE) is:  128813667226.9057
# Root Mean Squared Error (RMSE) is:  358906.20951288333

# %%
x2 = dataset2['yr_built'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

print('Mean Absolute Error (MAE) is: ',metrics.mean_absolute_error(y2_test,y2_predict))
print('Mean Squared Error (MSE) is: ',metrics.mean_squared_error(y2_test,y2_predict))
print('Root Mean Squared Error (RMSE) is: ',np.sqrt(metrics.mean_squared_error(y2_test,y2_predict)))
# Out:
# Mean Absolute Error (MAE) is:  236183.43241571297
# Mean Squared Error (MSE) is:  143940637464.17493
# Root Mean Squared Error (RMSE) is:  379395.0941487975

# %% [markdown]
# ## We get minimum error in attribute 'sqft_living'

# %%
x2 = dataset2['sqft_living'].values.reshape(-1,1)

x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 1/3,random_state = 0)

regressor = LinearRegression()
regressor.fit(x2_train,y2_train)

y2_predict = regressor.predict(x2_test)

# %%
plt.scatter(x2_train,y2_train,color='Yellow')

# %%
plt.plot(x2_train,regressor.predict(x2_train),color='Blue')
plt.scatter(x2_train,y2_train,color='Yellow')
plt.title("Training Data Analysis")
plt.xlabel("sqft_living")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
plt.scatter(x2_test,y2_test,color='Red')

# %%
plt.plot(x2_train,regressor.predict(x2_train),color='Blue')
plt.scatter(x2_test,y2_test,color='Red')
plt.title("Testing Data Analysis")
plt.xlabel("sqft_living")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')
